# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurLima05/Desafios-RocketSeat-IA-/blob/main/Desafio1RS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dicionário de faturamento
dict_faturamento = {
    'data_ref': [
        '2023-01-01',
        '2020-02-01',
        '2021-03-01',
        '2022-04-01',
        '2023-05-01',
        '2023-06-01',
        '2020-07-01',
        '2021-08-01',
        '2022-09-01',
        '2023-10-01',
        '2022-11-01',
        '2023-12-01',
        ],
    'valor': [
        400000,
        890000,
        760000,
        430000,
        920000,
        340000,
        800000,
        500000,
        200000,
        900000,
        570000,
        995000,
        ]
}

# %%
df = pd.DataFrame(dict_faturamento)

media_vendas = df['valor'].mean()

print(media_vendas)
# Out:
# 642083.3333333334

# %%
df['data_ref'] = pd.to_datetime(df['data_ref'])

# %%
df = df.sort_values(by = 'data_ref')
df
# Out:
#      data_ref   valor
# 1  2020-02-01  890000
# 6  2020-07-01  800000
# 2  2021-03-01  760000
# 7  2021-08-01  500000
# 3  2022-04-01  430000
# 8  2022-09-01  200000
# 10 2022-11-01  570000
# 0  2023-01-01  400000
# 4  2023-05-01  920000
# 5  2023-06-01  340000
# 9  2023-10-01  900000
# 11 2023-12-01  995000

# %%
df['data_ref'] = pd.to_datetime(df['data_ref'])

df = df.sort_values(by='data_ref')

plt.figure(figsize=(12, 6))
plt.bar(df['data_ref'].dt.strftime('%Y-%m'), df['valor'], color='royalblue')

plt.xlabel("Mês de Referência", fontsize=12)
plt.ylabel("Valor (R$)", fontsize=12)
plt.title("Faturamento por Mês", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['data_ref'].dt.strftime('%Y-%m'), df['valor'], marker='o', linestyle='-', color='royalblue', linewidth=2, markersize=8)


plt.xlabel("Mês de Referência", fontsize=12)
plt.ylabel("Valor (R$)", fontsize=12)
plt.title("Faturamento por Mês", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)


plt.show()
